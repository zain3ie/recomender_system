# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm

# %% [markdown]
# ## 1. importing data

# %% [markdown]
# ### load data

# %%
anime = pd.read_csv('data/anime.csv')
anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %% [markdown]
# ### check data shapes & types

# %%
anime.shape
# Out:
# (12294, 7)

# %%
anime.dtypes
# Out:
# anime_id      int64
# name         object
# genre        object
# type         object
# episodes     object
# rating      float64
# members       int64
# dtype: object

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %% [markdown]
# ### check duplicates data

# %%
anime.duplicated(subset=['anime_id']).sum()
# Out:
# 0

# %%
anime.duplicated(subset=['name', 'type']).sum()
# Out:
# 0

# %% [markdown]
# ### handle episodes with `Unknown` value

# %%
(anime.episodes == 'Unknown').sum()
# Out:
# 340

# %%
anime.episodes.replace('Unknown', np.nan, inplace=True)

# %% [markdown]
# ### set `anime_id` as index

# %%
anime = anime.set_index('anime_id', drop=True)
anime.head()
# Out:
#                                       name  \
# anime_id
# 32281                       Kimi no Na wa.
# 5114      Fullmetal Alchemist: Brotherhood
# 28977                             Gintama°
# 9253                           Steins;Gate
# 9969                         Gintama&#039;
#
#                                                       genre   type episodes  \
# anime_id
# 32281                  Drama, Romance, School, Supernatural  Movie        1
# 5114      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 28977     Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 9253                                       Sci-Fi, Thriller     TV       24
# 9969      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
#
#           rating  members
# anime_id
# 32281       9.37   200630
# 5114        9.26   793665
# 28977       9.25   114262
# 9253        9.17   673572
# 9969        9.16   151266

# %% [markdown]
# ### create load function

# %%
def load_anime_data(anime_path):
    '''
    function to load anime data

    parameters
    ----------
    anime_path : str
        path of anime data (.csv)

    returns
    -------
    anime_data : pandas dataframe
        anime data
    '''
    
    # load data
    anime = pd.read_csv(anime_path)
    print('data shape:', anime.shape)
    
    # change string 'Unknown' with NaN
    anime.episodes.replace('Unknown', np.nan, inplace=True)

    # set track_id as index
    anime = anime.set_index('anime_id', drop=True)

    return anime

# %%
anime = load_anime_data('data/anime.csv')
# Out:
# data shape: (12294, 7)

# %%
anime.head()
# Out:
#                                       name  \
# anime_id
# 32281                       Kimi no Na wa.
# 5114      Fullmetal Alchemist: Brotherhood
# 28977                             Gintama°
# 9253                           Steins;Gate
# 9969                         Gintama&#039;
#
#                                                       genre   type episodes  \
# anime_id
# 32281                  Drama, Romance, School, Supernatural  Movie        1
# 5114      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 28977     Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 9253                                       Sci-Fi, Thriller     TV       24
# 9969      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
#
#           rating  members
# anime_id
# 32281       9.37   200630
# 5114        9.26   793665
# 28977       9.25   114262
# 9253        9.17   673572
# 9969        9.16   151266

# %% [markdown]
# ## 2. data preparation

# %% [markdown]
# ### numerical features

# %%
anime.head().T
# Out:
# anime_id                                 32281  \
# name                            Kimi no Na wa.
# genre     Drama, Romance, School, Supernatural
# type                                     Movie
# episodes                                     1
# rating                                    9.37
# members                                 200630
#
# anime_id                                              5114   \
# name                       Fullmetal Alchemist: Brotherhood
# genre     Action, Adventure, Drama, Fantasy, Magic, Mili...
# type                                                     TV
# episodes                                                 64
# rating                                                 9.26
# members                                              793665
#
# anime_id                                              28977             9253   \
# name                                               Gintama°       Steins;Gate
# genre     Action, Comedy, Historical, Parody, Samurai, S...  Sci-Fi, Thriller
# type                                                     TV                TV
# episodes                                                 51                24
# rating                                                 9.25              9.17
# members                                              114262            673572
#
# anime_id                                              9969
# name                                          Gintama&#039;
# genre     Action, Comedy, Historical, Parody, Samurai, S...
# type                                                     TV
# episodes                                                 51
# rating                                                 9.16
# members                                              151266

# %%
# set numerical feature columns
num_cols = ['episodes', 'rating', 'members']

# %%
# create numerical features anime
anime_num = anime[num_cols]
anime_num.head()
# Out:
#          episodes  rating  members
# anime_id
# 32281           1    9.37   200630
# 5114           64    9.26   793665
# 28977          51    9.25   114262
# 9253           24    9.17   673572
# 9969           51    9.16   151266

# %%
anime_num.shape
# Out:
# (12294, 3)

# %%
# create & fitting object
scaler = MinMaxScaler()
scaler.fit(anime_num)
# Out:
# MinMaxScaler()

# %%
# get normalize data
anime_num_norm = pd.DataFrame(scaler.transform(anime_num))
anime_num_norm.index = anime_num.index
anime_num_norm.columns = anime_num.columns

anime_num_norm.head()
# Out:
#           episodes    rating   members
# anime_id
# 32281     0.000000  0.924370  0.197872
# 5114      0.034673  0.911164  0.782770
# 28977     0.027518  0.909964  0.112689
# 9253      0.012658  0.900360  0.664325
# 9969      0.027518  0.899160  0.149186

# %%
# validation
anime_num_norm.describe()
# Out:
#            episodes        rating       members
# count  11954.000000  12064.000000  12294.000000
# mean       0.006264      0.576699      0.017818
# std        0.025793      0.123259      0.054068
# min        0.000000      0.000000      0.000000
# 25%        0.000000      0.505402      0.000217
# 50%        0.000550      0.588235      0.001524
# 75%        0.006054      0.661465      0.009303
# max        1.000000      1.000000      1.000000

# %% [markdown]
# ### create numerical vectorized function

# %%
def numerical_vectorizer(data, num_cols):
    '''
    create numerical vector from a given data

    parameters
    ----------
    data : pandas dataframe
        sample data

    num_cols : list
        choosen numerical columns

    returns
    -------
    data_num_clean : pandas dataframe
        sample data with vectorized numerical columns
    '''
    
    data = data.copy()

    # filter data
    data_num = data[num_cols]

    # transform data
    scaler = MinMaxScaler()
    scaler.fit(data_num)

    data_num_clean = pd.DataFrame(scaler.transform(data_num))
    data_num_clean.index = data_num.index
    data_num_clean.columns = data_num.columns

    print('shape of original data:', data.shape)
    print('shape of numerical data:', data_num_clean.shape)

    return data_num_clean

# %%
anime_num = numerical_vectorizer(data=anime, num_cols=num_cols)
# Out:
# shape of original data: (12294, 6)
# shape of numerical data: (12294, 3)

# %%
anime_num.head()
# Out:
#           episodes    rating   members
# anime_id
# 32281     0.000000  0.924370  0.197872
# 5114      0.034673  0.911164  0.782770
# 28977     0.027518  0.909964  0.112689
# 9253      0.012658  0.900360  0.664325
# 9969      0.027518  0.899160  0.149186

# %% [markdown]
# ### categorical features

# %%
# set categorical feature columns
cat_cols = ['genre', 'type']

# %%
# create categorical features anime
anime_cat = anime[cat_cols]
anime_cat.head()
# Out:
#                                                       genre   type
# anime_id
# 32281                  Drama, Romance, School, Supernatural  Movie
# 5114      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV
# 28977     Action, Comedy, Historical, Parody, Samurai, S...     TV
# 9253                                       Sci-Fi, Thriller     TV
# 9969      Action, Comedy, Historical, Parody, Samurai, S...     TV

# %%
anime_cat.shape
# Out:
# (12294, 2)

# %%
anime_genre = anime_cat.genre.str.get_dummies(sep=',').add_prefix('genre_')
anime_cat = anime_cat.drop('genre', axis=1)
anime_cat = anime_cat.join(anime_genre)

anime_cat.head()
# Out:
#            type  genre_ Adventure  genre_ Cars  genre_ Comedy  \
# anime_id
# 32281     Movie                 0            0              0
# 5114         TV                 1            0              0
# 28977        TV                 0            0              1
# 9253         TV                 0            0              0
# 9969         TV                 0            0              1
#
#           genre_ Dementia  genre_ Demons  genre_ Drama  genre_ Ecchi  \
# anime_id
# 32281                   0              0             0             0
# 5114                    0              0             1             0
# 28977                   0              0             0             0
# 9253                    0              0             0             0
# 9969                    0              0             0             0
#
#           genre_ Fantasy  genre_ Game  ...  genre_Shoujo  genre_Shounen  \
# anime_id                               ...
# 32281                  0            0  ...             0              0
# 5114                   1            0  ...             0              0
# 28977                  0            0  ...             0              0
# 9253                   0            0  ...             0              0
# 9969                   0            0  ...             0              0
#
#           genre_Slice of Life  genre_Space  genre_Sports  genre_Super Power  \
# anime_id
# 32281                       0            0             0                  0
# 5114                        0            0             0                  0
# 28977                       0            0             0                  0
# 9253                        0            0             0                  0
# 9969                        0            0             0                  0
#
#           genre_Supernatural  genre_Thriller  genre_Vampire  genre_Yaoi
# anime_id
# 32281                      0               0              0           0
# 5114                       0               0              0           0
# 28977                      0               0              0           0
# 9253                       0               0              0           0
# 9969                       0               0              0           0
#
# [5 rows x 83 columns]

# %%
anime_type = anime_cat.type.str.get_dummies().add_prefix('type_')
anime_cat = anime_cat.drop('type', axis=1)
anime_cat = anime_cat.join(anime_type)

anime_cat.head()
# Out:
#           genre_ Adventure  genre_ Cars  genre_ Comedy  genre_ Dementia  \
# anime_id
# 32281                    0            0              0                0
# 5114                     1            0              0                0
# 28977                    0            0              1                0
# 9253                     0            0              0                0
# 9969                     0            0              1                0
#
#           genre_ Demons  genre_ Drama  genre_ Ecchi  genre_ Fantasy  \
# anime_id
# 32281                 0             0             0               0
# 5114                  0             1             0               1
# 28977                 0             0             0               0
# 9253                  0             0             0               0
# 9969                  0             0             0               0
#
#           genre_ Game  genre_ Harem  ...  genre_Supernatural  genre_Thriller  \
# anime_id                             ...
# 32281               0             0  ...                   0               0
# 5114                0             0  ...                   0               0
# 28977               0             0  ...                   0               0
# 9253                0             0  ...                   0               0
# 9969                0             0  ...                   0               0
#
#           genre_Vampire  genre_Yaoi  type_Movie  type_Music  type_ONA  \
# anime_id
# 32281                 0           0           1           0         0
# 5114                  0           0           0           0         0
# 28977                 0           0           0           0         0
# 9253                  0           0           0           0         0
# 9969                  0           0           0           0         0
#
#           type_OVA  type_Special  type_TV
# anime_id
# 32281            0             0        0
# 5114             0             0        1
# 28977            0             0        1
# 9253             0             0        1
# 9969             0             0        1
#
# [5 rows x 88 columns]

# %%
anime_cat.shape
# Out:
# (12294, 88)

# %% [markdown]
# ### create categorical vectorized function

# %%
def categorical_vectorizer(data, cat_cols):
    '''
    create categorical vector from a given data

    parameters
    ----------
    data : pandas dataframe
        sample data

    cat_cols : list
        choosen categorical columns

    returns
    -------
    data_num_clean : pandas dataframe
        sample data with vectorized categorical columns
    '''
    
    data = data.copy()

    # filter data
    data_cat = data[cat_cols]

    # one hot encoding column genre
    anime_genre = data_cat.genre.str.get_dummies(sep=',').add_prefix('genre_')
    
    # one hot encoding column type
    anime_type = data_cat.type.str.get_dummies().add_prefix('type_')
    
    data_cat_clean = data_cat.drop(['genre', 'type'], axis=1)
    data_cat_clean = data_cat_clean.join(anime_genre).join(anime_type)

    print('shape of original data:', data.shape)
    print('shape of numerical data:', data_cat_clean.shape)

    return data_cat_clean

# %%
anime_cat = categorical_vectorizer(data=anime, cat_cols=cat_cols)
# Out:
# shape of original data: (12294, 6)
# shape of numerical data: (12294, 88)

# %%
anime_cat.head()
# Out:
#           genre_ Adventure  genre_ Cars  genre_ Comedy  genre_ Dementia  \
# anime_id
# 32281                    0            0              0                0
# 5114                     1            0              0                0
# 28977                    0            0              1                0
# 9253                     0            0              0                0
# 9969                     0            0              1                0
#
#           genre_ Demons  genre_ Drama  genre_ Ecchi  genre_ Fantasy  \
# anime_id
# 32281                 0             0             0               0
# 5114                  0             1             0               1
# 28977                 0             0             0               0
# 9253                  0             0             0               0
# 9969                  0             0             0               0
#
#           genre_ Game  genre_ Harem  ...  genre_Supernatural  genre_Thriller  \
# anime_id                             ...
# 32281               0             0  ...                   0               0
# 5114                0             0  ...                   0               0
# 28977               0             0  ...                   0               0
# 9253                0             0  ...                   0               0
# 9969                0             0  ...                   0               0
#
#           genre_Vampire  genre_Yaoi  type_Movie  type_Music  type_ONA  \
# anime_id
# 32281                 0           0           1           0         0
# 5114                  0           0           0           0         0
# 28977                 0           0           0           0         0
# 9253                  0           0           0           0         0
# 9969                  0           0           0           0         0
#
#           type_OVA  type_Special  type_TV
# anime_id
# 32281            0             0        0
# 5114             0             0        1
# 28977            0             0        1
# 9253             0             0        1
# 9969             0             0        1
#
# [5 rows x 88 columns]

# %% [markdown]
# ### combine numerical and categorical features

# %%
anime_ready = pd.concat((anime_num, anime_cat), axis=1)
anime_ready.head()
# Out:
#           episodes    rating   members  genre_ Adventure  genre_ Cars  \
# anime_id
# 32281     0.000000  0.924370  0.197872                 0            0
# 5114      0.034673  0.911164  0.782770                 1            0
# 28977     0.027518  0.909964  0.112689                 0            0
# 9253      0.012658  0.900360  0.664325                 0            0
# 9969      0.027518  0.899160  0.149186                 0            0
#
#           genre_ Comedy  genre_ Dementia  genre_ Demons  genre_ Drama  \
# anime_id
# 32281                 0                0              0             0
# 5114                  0                0              0             1
# 28977                 1                0              0             0
# 9253                  0                0              0             0
# 9969                  1                0              0             0
#
#           genre_ Ecchi  ...  genre_Supernatural  genre_Thriller  \
# anime_id                ...
# 32281                0  ...                   0               0
# 5114                 0  ...                   0               0
# 28977                0  ...                   0               0
# 9253                 0  ...                   0               0
# 9969                 0  ...                   0               0
#
#           genre_Vampire  genre_Yaoi  type_Movie  type_Music  type_ONA  \
# anime_id
# 32281                 0           0           1           0         0
# 5114                  0           0           0           0         0
# 28977                 0           0           0           0         0
# 9253                  0           0           0           0         0
# 9969                  0           0           0           0         0
#
#           type_OVA  type_Special  type_TV
# anime_id
# 32281            0             0        0
# 5114             0             0        1
# 28977            0             0        1
# 9253             0             0        1
# 9969             0             0        1
#
# [5 rows x 91 columns]

# %%
anime_ready.shape
# Out:
# (12294, 91)

# %% [markdown]
# ## 3. content based recommendations

# %%
def jaccard_similarity(vec_a, vec_b):
    '''
    calculate jaccard similarity
    '''
    
    # convert to vector
    vec_a = np.array(vec_a)
    vec_b = np.array(vec_b)

    # find intersection & number of items
    n_intersect = np.sum((vec_a==1) & (vec_b==1))
    n_item = np.sum((vec_a==1) | (vec_b==1))

    # calculate similarity
    sim = n_intersect / n_item

    return sim

# %%
def euclidean_distance(vec_a, vec_b):
    '''
    calculate euclidean distance between vec a and vec b
    '''
    
    # transform to vector
    vec_a = np.array(vec_a)
    vec_B = np.array(vec_b)

    # calculate distance
    inside_the_root = np.sum((vec_a - vec_b)**2)
    dist = np.sqrt(inside_the_root)

    return dist

def euclidean_similarity(vec_a, vec_b):
    '''
    compute euclidean similarity between vec a and vec b
    '''
    
    # calculate Euclidean distance
    dist_ab = euclidean_distance(vec_a, vec_b)

    # calculate similarity
    sim = 1.0 / (1.0 + dist_ab)

    return sim

# %%
def cosine_similarity(vec_a, vec_b):
    '''
    calculate cosine similarity between vec a and vec b
    '''
    
    # find norm
    norm_a = np.linalg.norm(vec_a)
    norm_b = np.linalg.norm(vec_b)

    # find dot
    dot_ab = np.dot(vec_a, vec_b)

    # calculate similarity
    sim = dot_ab / (norm_a * norm_b)

    return sim

# %%
def pearson_similarity(vec_a, vec_b):
    '''
    calculate pearson similarity between vec a and vec b
    '''
    
    # calculate numerator & denominator
    numerator = np.cov(vec_a, vec_b)[0, 1]
    denominator = np.sqrt(np.cov(vec_a) * np.cov(vec_b))

    # calculate similarity
    sim = numerator / denominator

    return sim

# %%
anime_a = anime_ready.loc[9969]
anime_b = anime_ready.loc[918]

# calculate similarity
jac = jaccard_similarity(anime_a, anime_b)
euc = euclidean_similarity(anime_a, anime_b)
cos = cosine_similarity(anime_a, anime_b)
per = pearson_similarity(anime_a, anime_b)

jac, euc, cos, per
# Out:
# (1.0, 0.8327197458081089, 0.9977333332184977, 0.9975025888054089)

# %% [markdown]
# ### find similar items based on user last consumed item

# %%
latest_anime_id = 5114
anime.loc[[latest_anime_id]].T
# Out:
# anime_id                                               5114
# name                       Fullmetal Alchemist: Brotherhood
# genre     Action, Adventure, Drama, Fantasy, Magic, Mili...
# type                                                     TV
# episodes                                                 64
# rating                                                 9.26
# members                                              793665

# %%
# generate similarity score
n_anime = len(anime_num.index)
similarity_score = np.zeros(n_anime)

anime_reference = anime_num.loc[latest_anime_id]

# iterate whole anime (anime_num)
for i, anime_id in enumerate(tqdm(anime_num.index)):
    # extract anime sample
    anime_sample = anime_num.loc[anime_id]

    # calculate similarity
    sim = euclidean_similarity(anime_reference, anime_sample)

    # append
    similarity_score[i] = sim
# Out:
# 100%|███████████████████████████████████| 12294/12294 [00:07<00:00, 1702.34it/s]

# %%
similarity_score
# Out:
# array([0.63048782, 1.        , 0.59875933, ..., 0.51456744, 0.51630552,
#        0.52450925])

# %%
# sort in descending orders of similarity_score
sorted_id = np.argsort(similarity_score)[::-1]

# return n top similar anime
n = 5
top_anime_id = anime_ready.index[sorted_id[1:n+1]]
top_anime_id
# Out:
# Int64Index([1575, 9253, 6547, 16498, 4224], dtype='int64', name='anime_id')

# %%
anime.loc[[latest_anime_id] + list(top_anime_id)].T
# Out:
# anime_id                                              5114   \
# name                       Fullmetal Alchemist: Brotherhood
# genre     Action, Adventure, Drama, Fantasy, Magic, Mili...
# type                                                     TV
# episodes                                                 64
# rating                                                 9.26
# members                                              793665
#
# anime_id                                              1575              9253   \
# name                        Code Geass: Hangyaku no Lelouch       Steins;Gate
# genre     Action, Mecha, Military, School, Sci-Fi, Super...  Sci-Fi, Thriller
# type                                                     TV                TV
# episodes                                                 25                24
# rating                                                 8.83              9.17
# members                                              715151            673572
#
# anime_id                                        6547   \
# name                                     Angel Beats!
# genre     Action, Comedy, Drama, School, Supernatural
# type                                               TV
# episodes                                           13
# rating                                           8.39
# members                                        717796
#
# anime_id                                         16498  \
# name                                Shingeki no Kyojin
# genre     Action, Drama, Fantasy, Shounen, Super Power
# type                                                TV
# episodes                                            25
# rating                                            8.54
# members                                         896229
#
# anime_id                                   4224
# name                                   Toradora!
# genre     Comedy, Romance, School, Slice of Life
# type                                          TV
# episodes                                      25
# rating                                      8.45
# members                                   633817

# %% [markdown]
# ### create anime recomendation function

# %%
def anime_recommendation(anime_id, n, anime_data, similarity_func):
    '''
    recommend n item based on latest watch anime_id
    '''
    
    # generate similarity score
    n_anime = len(anime_data.index)
    similarity_score = np.zeros(n_anime)

    anime_reference = anime_data.loc[latest_anime_id]
    
    # iterate whole anime (anime_num)
    for i, anime_id in enumerate(tqdm(anime_data.index)):
        # extract anime sample
        anime_sample = anime_data.loc[anime_id]

        # calculate similarity
        sim = similarity_func(anime_reference, anime_sample)

        # append
        similarity_score[i] = sim
    
    # sort in descending orders of similarity_score
    sorted_id = np.argsort(similarity_score)[::-1]

    # return n top similar anime
    top_anime_id = anime_ready.index[sorted_id[1:n+1]]

    return top_anime_id

# %%
reference_anime_id = 5114
anime.loc[[reference_anime_id]].T
# Out:
# anime_id                                               5114
# name                       Fullmetal Alchemist: Brotherhood
# genre     Action, Adventure, Drama, Fantasy, Magic, Mili...
# type                                                     TV
# episodes                                                 64
# rating                                                 9.26
# members                                              793665

# %% [markdown]
# ### categorical features + jaccard similarity function

# %%
top_anime_id = anime_recommendation(
    anime_id=reference_anime_id,
    n=10,
    anime_data=anime_cat,
    similarity_func=jaccard_similarity
)

anime.loc[[reference_anime_id] + list(top_anime_id)].T
# Out:
# 100%|███████████████████████████████████| 12294/12294 [00:02<00:00, 4534.28it/s]
# anime_id                                              5114   \
# name                       Fullmetal Alchemist: Brotherhood
# genre     Action, Adventure, Drama, Fantasy, Magic, Mili...
# type                                                     TV
# episodes                                                 64
# rating                                                 9.26
# members                                              793665
#
# anime_id                                              121    \
# name                                    Fullmetal Alchemist
# genre     Action, Adventure, Comedy, Drama, Fantasy, Mag...
# type                                                     TV
# episodes                                                 51
# rating                                                 8.33
# members                                              600384
#
# anime_id                                       31741  \
# name                     Magi: Sinbad no Bouken (TV)
# genre     Action, Adventure, Fantasy, Magic, Shounen
# type                                              TV
# episodes                                          13
# rating                                          8.22
# members                                        73480
#
# anime_id                                     1775   \
# name                           Jikuu Tenshou Nazca
# genre     Action, Adventure, Drama, Fantasy, Magic
# type                                            TV
# episodes                                        12
# rating                                        5.88
# members                                       3080
#
# anime_id                                       8086   \
# name                  Densetsu no Yuusha no Densetsu
# genre     Action, Adventure, Fantasy, Magic, Shounen
# type                                              TV
# episodes                                          24
# rating                                          7.83
# members                                       130689
#
# anime_id                                       18115  \
# name                      Magi: The Kingdom of Magic
# genre     Action, Adventure, Fantasy, Magic, Shounen
# type                                              TV
# episodes                                          25
# rating                                           8.5
# members                                       245026
#
# anime_id                                       14513  \
# name                    Magi: The Labyrinth of Magic
# genre     Action, Adventure, Fantasy, Magic, Shounen
# type                                              TV
# episodes                                          25
# rating                                          8.24
# members                                       317513
#
# anime_id                                       28833  \
# name           Chain Chronicle: Haecceitas no Hikari
# genre     Action, Adventure, Fantasy, Magic, Shounen
# type                                              TV
# episodes                                          12
# rating                                           NaN
# members                                         5678
#
# anime_id                                        473    \
# name                                   Tide-Line Blue
# genre     Action, Adventure, Drama, Military, Shounen
# type                                               TV
# episodes                                           12
# rating                                           6.77
# members                                          4670
#
# anime_id                                              9135   \
# name          Fullmetal Alchemist: The Sacred Star of Milos
# genre     Action, Adventure, Comedy, Drama, Fantasy, Mag...
# type                                                  Movie
# episodes                                                  1
# rating                                                  7.5
# members                                               87944
#
# anime_id                                              6702
# name                                             Fairy Tail
# genre     Action, Adventure, Comedy, Fantasy, Magic, Sho...
# type                                                     TV
# episodes                                                175
# rating                                                 8.22
# members                                              584590

# %% [markdown]
# ### numerical features + euclidean similarity function

# %%
top_anime_id = anime_recommendation(
    anime_id=reference_anime_id,
    n=10,
    anime_data=anime_num,
    similarity_func=euclidean_similarity
)

anime.loc[[reference_anime_id] + list(top_anime_id)].T
# Out:
# 100%|███████████████████████████████████| 12294/12294 [00:06<00:00, 1802.29it/s]
# anime_id                                              5114   \
# name                       Fullmetal Alchemist: Brotherhood
# genre     Action, Adventure, Drama, Fantasy, Magic, Mili...
# type                                                     TV
# episodes                                                 64
# rating                                                 9.26
# members                                              793665
#
# anime_id                                              1575              9253   \
# name                        Code Geass: Hangyaku no Lelouch       Steins;Gate
# genre     Action, Mecha, Military, School, Sci-Fi, Super...  Sci-Fi, Thriller
# type                                                     TV                TV
# episodes                                                 25                24
# rating                                                 8.83              9.17
# members                                              715151            673572
#
# anime_id                                        6547   \
# name                                     Angel Beats!
# genre     Action, Comedy, Drama, School, Supernatural
# type                                               TV
# episodes                                           13
# rating                                           8.39
# members                                        717796
#
# anime_id                                         16498  \
# name                                Shingeki no Kyojin
# genre     Action, Drama, Fantasy, Shounen, Super Power
# type                                                TV
# episodes                                            25
# rating                                            8.54
# members                                         896229
#
# anime_id                                   4224   \
# name                                   Toradora!
# genre     Comedy, Romance, School, Slice of Life
# type                                          TV
# episodes                                      25
# rating                                      8.45
# members                                   633817
#
# anime_id                                              10620  \
# name                                       Mirai Nikki (TV)
# genre     Action, Mystery, Psychological, Shounen, Super...
# type                                                     TV
# episodes                                                 26
# rating                                                 8.07
# members                                              657190
#
# anime_id                                      11757  \
# name                               Sword Art Online
# genre     Action, Adventure, Fantasy, Game, Romance
# type                                             TV
# episodes                                         25
# rating                                         7.83
# members                                      893100
#
# anime_id                                              19815  \
# name                                        No Game No Life
# genre     Adventure, Comedy, Ecchi, Fantasy, Game, Super...
# type                                                     TV
# episodes                                                 12
# rating                                                 8.47
# members                                              602291
#
# anime_id                                              121    \
# name                                    Fullmetal Alchemist
# genre     Action, Adventure, Comedy, Drama, Fantasy, Mag...
# type                                                     TV
# episodes                                                 51
# rating                                                 8.33
# members                                              600384
#
# anime_id                                              2904
# name                     Code Geass: Hangyaku no Lelouch R2
# genre     Action, Drama, Mecha, Military, Sci-Fi, Super ...
# type                                                     TV
# episodes                                                 25
# rating                                                 8.98
# members                                              572888

# %% [markdown]
# ### numerical + categorical features + pearson similarity function

# %%
top_anime_id = anime_recommendation(
    anime_id=reference_anime_id,
    n=10,
    anime_data=anime_ready,
    similarity_func=pearson_similarity
)

anime.loc[[reference_anime_id] + list(top_anime_id)].T
# Out:
# 100%|███████████████████████████████████| 12294/12294 [00:06<00:00, 1763.51it/s]
# anime_id                                              5114   \
# name                       Fullmetal Alchemist: Brotherhood
# genre     Action, Adventure, Drama, Fantasy, Magic, Mili...
# type                                                     TV
# episodes                                                 64
# rating                                                 9.26
# members                                              793665
#
# anime_id                                     31445  \
# name      Minna Atsumare! Falcom Gakuen 3rd Season
# genre               Comedy, Parody, School, Seinen
# type                                            TV
# episodes                                       NaN
# rating                                         NaN
# members                                        245
#
# anime_id                                     31422                 33737  \
# name      Minami Kamakura Koukou Joshi Jitensha-bu  Megaton-kyuu Musashi
# genre                      School, Shounen, Sports         Mecha, School
# type                                            TV                    TV
# episodes                                       NaN                   NaN
# rating                                         NaN                   NaN
# members                                       2216                   173
#
# anime_id                                   33788              33479  \
# name      Marginal#4: Kiss kara Tsukuru Big Bang  Muzumuzu Eighteen
# genre                              Music, Shoujo      Slice of Life
# type                                          TV                 TV
# episodes                                     NaN                NaN
# rating                                       NaN                3.8
# members                                     1766                 72
#
# anime_id                           32892                    32518  \
# name      Himitsukessha Taka no Tsume GT  Shoujo kara Shoujo e...
# genre        Comedy, Parody, Super Power                   Hentai
# type                                 ONA                      OVA
# episodes                             NaN                      NaN
# rating                              5.14                     7.08
# members                               80                     1964
#
# anime_id                     33026  \
# name                 Time Bokan 24
# genre     Adventure, Comedy, Mecha
# type                            TV
# episodes                       NaN
# rating                        5.28
# members                       2243
#
# anime_id                                              32900  \
# name      Mahouka Koukou no Rettousei Movie: Hoshi wo Yo...
# genre     Action, Magic, Romance, School, Sci-Fi, Supern...
# type                                                  Movie
# episodes                                                  1
# rating                                                  NaN
# members                                               13884
#
# anime_id                                              1735
# name                                     Naruto: Shippuuden
# genre     Action, Comedy, Martial Arts, Shounen, Super P...
# type                                                     TV
# episodes                                                NaN
# rating                                                 7.94
# members                                              533578
